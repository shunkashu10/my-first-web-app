# %% [markdown]
# <a href="https://colab.research.google.com/github/shunkashu10/my-first-web-app/blob/main/Untitled0_ipynb_%E3%81%AE%E3%82%B3%E3%83%94%E3%83%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Google Driveと接続を行います。これを行うことで、Driveにあるデータにアクセスできるようになります。
# 下記セルを実行すると、Googleアカウントのログインを求められますのでログインしてください。
from google.colab import drive
drive.mount('/content/drive')

import os
# 作業フォルダへの移動を行います。
# もしアップロードした場所が異なる場合は作業場所を変更してください。
os.chdir('/content/drive/MyDrive/DA_WB/2章/data')

# Google DriveのMyDrive直下の内容を表示して、正しいパスを確認してください。
# print("\n--- Google Drive MyDrive Contents ---")
# !ls -F '/content/drive/MyDrive/'
# print("-------------------------------------")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df_sales_2021 = pd.read_csv('売上テーブル_2021.csv', encoding= 'SJIS')
df_sales_2021.head()
# Out:
#         売上ID       顧客ID       契約ID       売上日       売上
# 0  S-1000072  C-1000222  N-1002716  2021/1/1   6000.0
# 1  S-1000073  C-1000458  N-1000683  2021/1/1  50000.0
# 2  S-1000074  C-1000599  N-1001044  2021/1/1  10000.0
# 3  S-1000075  C-1000599  N-1001042  2021/1/1  10000.0
# 4  S-1000076  C-1000599  N-1001041  2021/1/1  10000.0

# %%
df_sales_2022 = pd.read_csv('売上テーブル_2022.csv', encoding='SJIS')
df_sales_2022.head()
# Out:
#         売上ID       顧客ID       契約ID       売上日     売上
# 0  S-1125052  C-1000892  N-1001965  2022/1/1  29000
# 1  S-1125053  C-1001352  N-1003792  2022/1/1  10000
# 2  S-1125054  C-1000547  N-1000944  2022/1/1  30000
# 3  S-1125055  C-1000072  N-1000075  2022/1/1  10000
# 4  S-1125056  C-1000222  N-1000275  2022/1/1  50000

# %%
df_customer = pd.read_csv('顧客テーブル.csv', encoding='SJIS')
df_customer.head()
# Out:
#         顧客ID   顧客区分         顧客名    地域 都道府県 市区町村      初回契約日    社員ID  顧客満足度
# 0  C-1000007  企業規模小    株式会社鈴木工業  関東地方  東京都  台東区   2015/1/9  101782      3
# 1  C-1000008    その他    株式会社中村工業    四国  徳島県  徳島市  2015/1/15  100726      3
# 2  C-1000009  企業規模中  大和屋根工事合同会社  関西地方  三重県   津市  2015/1/19  101305      2
# 3  C-1000010  企業規模大     株式会社ユタカ  関東地方  千葉県  松戸市  2015/1/19  107576      5
# 4  C-1000011  企業規模中    合資会社橋本商店  関東地方  東京都  大田区  2015/1/21  103152      1

# %%
df_sales = pd.concat([df_sales_2021, df_sales_2022], ignore_index=True)
df_sales.head()
# Out:
#         売上ID       顧客ID       契約ID       売上日       売上
# 0  S-1000072  C-1000222  N-1002716  2021/1/1   6000.0
# 1  S-1000073  C-1000458  N-1000683  2021/1/1  50000.0
# 2  S-1000074  C-1000599  N-1001044  2021/1/1  10000.0
# 3  S-1000075  C-1000599  N-1001042  2021/1/1  10000.0
# 4  S-1000076  C-1000599  N-1001041  2021/1/1  10000.0

# %%
df_sales.tall()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3601530470.py in <cell line: 0>()
# ----> 1 df_sales.tall()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'tall'

# %%
df_sales.tail
# Out:
# <bound method NDFrame.tail of             売上ID       顧客ID       契約ID         売上日       売上
# 0      S-1000072  C-1000222  N-1002716    2021/1/1   6000.0
# 1      S-1000073  C-1000458  N-1000683    2021/1/1  50000.0
# 2      S-1000074  C-1000599  N-1001044    2021/1/1  10000.0
# 3      S-1000075  C-1000599  N-1001042    2021/1/1  10000.0
# 4      S-1000076  C-1000599  N-1001041    2021/1/1  10000.0
# ...          ...        ...        ...         ...      ...
# 75440  S-1177220  C-1001260  N-1004684  2022/12/30   9000.0
# 75441  S-1177223  C-1000315  N-1004170  2022/12/30  21000.0
# 75442  S-1177224  C-1000094  N-1004169  2022/12/30  15000.0
# 75443  S-1177234  C-1001645  N-1004605  2022/12/30  13000.0
# 75444  S-1177235  C-1001714  N-1004814  2022/12/31  50000.0
#
# [75445 rows x 5 columns]>

# %%
df_sales.tail()
# Out:
#             売上ID       顧客ID       契約ID         売上日       売上
# 75440  S-1177220  C-1001260  N-1004684  2022/12/30   9000.0
# 75441  S-1177223  C-1000315  N-1004170  2022/12/30  21000.0
# 75442  S-1177224  C-1000094  N-1004169  2022/12/30  15000.0
# 75443  S-1177234  C-1001645  N-1004605  2022/12/30  13000.0
# 75444  S-1177235  C-1001714  N-1004814  2022/12/31  50000.0

# %%
print(len(df_sales_2021))
print(len(df_sales_2022))
print(len(df_sales))
# Out:
# 38895
# 36550
# 75445

# %%
df_sales_customer = pd.merge(df_sales, df_customer, on='顧客ID', how='left')
df_sales_customer.head()
# Out:
#         売上ID       顧客ID       契約ID       売上日       売上   顧客区分         顧客名  \
# 0  S-1000072  C-1000222  N-1002716  2021/1/1   6000.0    その他  合同会社グループ明伸
# 1  S-1000073  C-1000458  N-1000683  2021/1/1  50000.0  企業規模大    有限会社小川商事
# 2  S-1000074  C-1000599  N-1001044  2021/1/1  10000.0  企業規模中    吉田産業有限会社
# 3  S-1000075  C-1000599  N-1001042  2021/1/1  10000.0  企業規模中    吉田産業有限会社
# 4  S-1000076  C-1000599  N-1001041  2021/1/1  10000.0  企業規模中    吉田産業有限会社
#
#      地域 都道府県     市区町村      初回契約日      社員ID  顧客満足度
# 0  関西地方  大阪府   大阪市中央区   2016/1/1  105523.0    3.0
# 1  中部地方  愛知県  名古屋市中村区   2017/3/1  103462.0    2.0
# 2   北海道  北海道   札幌市中央区  2017/12/1  100173.0    4.0
# 3   北海道  北海道   札幌市中央区  2017/12/1  100173.0    4.0
# 4   北海道  北海道   札幌市中央区  2017/12/1  100173.0    4.0

# %%
print(len(df_sales))
print(len(df_sales_customer))
# Out:
# 75445
# 75445

# %%
df_sales_customer.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1821728547.py in <cell line: 0>()
# ----> 1 df_sales_customer.info()
#
# NameError: name 'df_sales_customer' is not defined

# %%
import pandas as pd
df_sales_2021 = pd.read_csv('売上テーブル_2021.csv', encoding= 'SJIS')
df_sales_2021.head()
# Out:
#         売上ID       顧客ID       契約ID       売上日       売上
# 0  S-1000072  C-1000222  N-1002716  2021/1/1   6000.0
# 1  S-1000073  C-1000458  N-1000683  2021/1/1  50000.0
# 2  S-1000074  C-1000599  N-1001044  2021/1/1  10000.0
# 3  S-1000075  C-1000599  N-1001042  2021/1/1  10000.0
# 4  S-1000076  C-1000599  N-1001041  2021/1/1  10000.0

# %%
df_sales_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75445 entries, 0 to 75444
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   売上ID    75445 non-null  object
#  1   顧客ID    75445 non-null  object
#  2   契約ID    75445 non-null  object
#  3   売上日     75445 non-null  object
#  4   売上      75443 non-null  float64
#  5   顧客区分    75443 non-null  object
#  6   顧客名     75443 non-null  object
#  7   地域      75443 non-null  object
#  8   都道府県    75443 non-null  object
#  9   市区町村    75357 non-null  object
#  10  初回契約日   75443 non-null  object
#  11  社員ID    75443 non-null  float64
#  12  顧客満足度   75443 non-null  float64
# dtypes: float64(3), object(10)
# memory usage: 7.5+ MB

# %%
df_sales_customer_loc[df_sales_customer['売上'].isnull()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1824755635.py in <cell line: 0>()
# ----> 1 df_sales_customer_loc[df_sales_customer['売上'].isnull()]
#
# NameError: name 'df_sales_customer_loc' is not defined

# %%
df_sales_customer.loc[df_sales_customer['顧客区分'].isnull]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1422123024.py in <cell line: 0>()
# ----> 1 df_sales_customer.loc[df_sales_customer['顧客区分'].isnull]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1187             axis = self.axis or 0
#    1188
# -> 1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
#    1191             return self._getitem_axis(maybe_callable, axis=axis)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/common.py in apply_if_callable(maybe_callable, obj, **kwargs)
#     382     """
#     383     if callable(maybe_callable):
# --> 384         return maybe_callable(obj, **kwargs)
#     385
#     386     return maybe_callable
#
# TypeError: Series.isnull() takes 1 positional argument but 2 were given

# %%
df_sales_customer.loc[df_sales_customer['顧客区分'].isnull()]
# Out:
#             売上ID       顧客ID       契約ID         売上日         売上 顧客区分  顧客名   地域  \
# 38889  S-1125994  C-9999993  N-9999999  2021/12/31        NaN  NaN  NaN  NaN
# 38893  S-1125998  C-9999993  N-9999999  2021/12/31  9999999.0  NaN  NaN  NaN
#
#       都道府県 市区町村 初回契約日  社員ID  顧客満足度
# 38889  NaN  NaN   NaN   NaN    NaN
# 38893  NaN  NaN   NaN   NaN    NaN

# %%
df_sales_customer.loc[df_sales_customer['売上'].isnull()]
# Out:
#             売上ID       顧客ID       契約ID         売上日  売上 顧客区分     顧客名    地域  \
# 38886  S-1125991  C-9999991  N-9999999  2021/12/31 NaN  その他  テスト会社A  関東地方
# 38889  S-1125994  C-9999993  N-9999999  2021/12/31 NaN  NaN     NaN   NaN
#
#       都道府県 市区町村     初回契約日      社員ID  顧客満足度
# 38886  東京都  新宿区  1990/1/1  999999.0   99.0
# 38889  NaN  NaN       NaN       NaN    NaN

# %%
df_sales_customer.describe()
# Out:
#                  売上           社員ID         顧客満足度
# count  7.544300e+04   75443.000000  75443.000000
# mean   3.076949e+04  103257.970057      3.436051
# std    9.159202e+04    9519.878995      1.564609
# min    0.000000e+00  100002.000000      1.000000
# 25%    1.300000e+04  101242.000000      3.000000
# 50%    2.900000e+04  102443.000000      4.000000
# 75%    5.000000e+04  105523.000000      4.000000
# max    9.999999e+06  999999.000000     99.000000

# %%
df_sales_customer.dropna(subset=['売上'], inplace=True)
df_sales_customer.head()
# Out:
#         売上ID       顧客ID       契約ID       売上日       売上   顧客区分         顧客名  \
# 0  S-1000072  C-1000222  N-1002716  2021/1/1   6000.0    その他  合同会社グループ明伸
# 1  S-1000073  C-1000458  N-1000683  2021/1/1  50000.0  企業規模大    有限会社小川商事
# 2  S-1000074  C-1000599  N-1001044  2021/1/1  10000.0  企業規模中    吉田産業有限会社
# 3  S-1000075  C-1000599  N-1001042  2021/1/1  10000.0  企業規模中    吉田産業有限会社
# 4  S-1000076  C-1000599  N-1001041  2021/1/1  10000.0  企業規模中    吉田産業有限会社
#
#      地域 都道府県     市区町村      初回契約日      社員ID  顧客満足度
# 0  関西地方  大阪府   大阪市中央区   2016/1/1  105523.0    3.0
# 1  中部地方  愛知県  名古屋市中村区   2017/3/1  103462.0    2.0
# 2   北海道  北海道   札幌市中央区  2017/12/1  100173.0    4.0
# 3   北海道  北海道   札幌市中央区  2017/12/1  100173.0    4.0
# 4   北海道  北海道   札幌市中央区  2017/12/1  100173.0    4.0

# %%
df_sales_customer.loc[df_sales_customer['売上'].isnull()]
# Out:
# Empty DataFrame
# Columns: [売上ID, 顧客ID, 契約ID, 売上日, 売上, 顧客区分, 顧客名, 地域, 都道府県, 市区町村, 初回契約日, 社員ID, 顧客満足度]
# Index: []

# %%
df_sales_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 75443 entries, 0 to 75444
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   売上ID    75443 non-null  object
#  1   顧客ID    75443 non-null  object
#  2   契約ID    75443 non-null  object
#  3   売上日     75443 non-null  object
#  4   売上      75443 non-null  float64
#  5   顧客区分    75442 non-null  object
#  6   顧客名     75442 non-null  object
#  7   地域      75442 non-null  object
#  8   都道府県    75442 non-null  object
#  9   市区町村    75356 non-null  object
#  10  初回契約日   75442 non-null  object
#  11  社員ID    75442 non-null  float64
#  12  顧客満足度   75442 non-null  float64
# dtypes: float64(3), object(10)
# memory usage: 10.1+ MB

# %%
df_sales_customer.loc[(df_sales_customer['売上']==9999999)|(df_sales_customer['売上']==0)]
# Out:
#             売上ID       顧客ID       契約ID         売上日         売上 顧客区分     顧客名  \
# 38885  S-1125990  C-9999991  N-9999999  2021/12/31  9999999.0  その他  テスト会社A
# 38887  S-1125992  C-9999992  N-9999999  2021/12/31  9999999.0  テスト  テスト会社B
# 38888  S-1125993  C-9999992  N-9999999  2021/12/31        0.0  テスト  テスト会社B
# 38890  S-1125995  C-9999991  N-9999999  2021/12/31  9999999.0  その他  テスト会社A
# 38891  S-1125996  C-9999991  N-9999999  2021/12/31        0.0  その他  テスト会社A
# 38892  S-1125997  C-9999992  N-9999999  2021/12/31  9999999.0  テスト  テスト会社B
# 38893  S-1125998  C-9999993  N-9999999  2021/12/31  9999999.0  NaN     NaN
# 38894  S-1125999  C-9999992  N-9999999  2021/12/31  9999999.0  テスト  テスト会社B
#
#          地域 都道府県  市区町村     初回契約日      社員ID  顧客満足度
# 38885  関東地方  東京都   新宿区  1990/1/1  999999.0   99.0
# 38887  関東地方  東京都  世田谷区  1990/1/1  999999.0   99.0
# 38888  関東地方  東京都  世田谷区  1990/1/1  999999.0   99.0
# 38890  関東地方  東京都   新宿区  1990/1/1  999999.0   99.0
# 38891  関東地方  東京都   新宿区  1990/1/1  999999.0   99.0
# 38892  関東地方  東京都  世田谷区  1990/1/1  999999.0   99.0
# 38893   NaN  NaN   NaN       NaN       NaN    NaN
# 38894  関東地方  東京都  世田谷区  1990/1/1  999999.0   99.0

# %%
df_sales_customer = df_sales_customer.loc[(df_sales_customer['売上']!=9999999)&(df_sales_customer['売上']!=0)]
print(len(df_sales_customer))
df_sales_customer.head()
# Out:
# 75435
#         売上ID       顧客ID       契約ID       売上日       売上   顧客区分         顧客名  \
# 0  S-1000072  C-1000222  N-1002716  2021/1/1   6000.0    その他  合同会社グループ明伸
# 1  S-1000073  C-1000458  N-1000683  2021/1/1  50000.0  企業規模大    有限会社小川商事
# 2  S-1000074  C-1000599  N-1001044  2021/1/1  10000.0  企業規模中    吉田産業有限会社
# 3  S-1000075  C-1000599  N-1001042  2021/1/1  10000.0  企業規模中    吉田産業有限会社
# 4  S-1000076  C-1000599  N-1001041  2021/1/1  10000.0  企業規模中    吉田産業有限会社
#
#      地域 都道府県     市区町村      初回契約日      社員ID  顧客満足度
# 0  関西地方  大阪府   大阪市中央区   2016/1/1  105523.0    3.0
# 1  中部地方  愛知県  名古屋市中村区   2017/3/1  103462.0    2.0
# 2   北海道  北海道   札幌市中央区  2017/12/1  100173.0    4.0
# 3   北海道  北海道   札幌市中央区  2017/12/1  100173.0    4.0
# 4   北海道  北海道   札幌市中央区  2017/12/1  100173.0    4.0

# %%
df_sales_customer['売上日'] = pd.to_datetime(df_sales_customer['売上日'])
df_sales_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 75435 entries, 0 to 75444
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   売上ID    75435 non-null  object
#  1   顧客ID    75435 non-null  object
#  2   契約ID    75435 non-null  object
#  3   売上日     75435 non-null  datetime64[ns]
#  4   売上      75435 non-null  float64
#  5   顧客区分    75435 non-null  object
#  6   顧客名     75435 non-null  object
#  7   地域      75435 non-null  object
#  8   都道府県    75435 non-null  object
#  9   市区町村    75349 non-null  object
#  10  初回契約日   75435 non-null  object
#  11  社員ID    75435 non-null  float64
#  12  顧客満足度   75435 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(9)
# memory usage: 10.1+ MB

# %%
df_sales_customer.loc[df_sales_customer['売上日'].dt.year==2022]
# Out:
#             売上ID       顧客ID       契約ID        売上日       売上   顧客区分  \
# 38895  S-1125052  C-1000892  N-1001965 2022-01-01  29000.0  企業規模中
# 38896  S-1125053  C-1001352  N-1003792 2022-01-01  10000.0  企業規模小
# 38897  S-1125054  C-1000547  N-1000944 2022-01-01  30000.0  企業規模小
# 38898  S-1125055  C-1000072  N-1000075 2022-01-01  10000.0  企業規模小
# 38899  S-1125056  C-1000222  N-1000275 2022-01-01  50000.0    その他
# ...          ...        ...        ...        ...      ...    ...
# 75440  S-1177220  C-1001260  N-1004684 2022-12-30   9000.0  企業規模小
# 75441  S-1177223  C-1000315  N-1004170 2022-12-30  21000.0  企業規模小
# 75442  S-1177224  C-1000094  N-1004169 2022-12-30  15000.0  企業規模中
# 75443  S-1177234  C-1001645  N-1004605 2022-12-30  13000.0  企業規模小
# 75444  S-1177235  C-1001714  N-1004814 2022-12-31  50000.0    その他
#
#                      顧客名    地域 都道府県     市区町村       初回契約日      社員ID  顧客満足度
# 38895           株式会社たんぽぽ  関西地方  大阪府  大阪市住之江区    2019/8/1  102434.0    2.0
# 38896            株式会社T＆K  関西地方  大阪府    大阪市港区    2021/5/1  100352.0    3.0
# 38897           三重木材合資会社  関西地方  兵庫県      西宮市   2017/10/1  101013.0    2.0
# 38898           有限会社フィール    四国  愛媛県      松山市    2015/4/1  100708.0    4.0
# 38899         合同会社グループ明伸  関西地方  大阪府   大阪市中央区    2016/1/1  105523.0    3.0
# ...                  ...   ...  ...      ...         ...       ...    ...
# 75440           有限会社大塚商店  関東地方  千葉県      松戸市  2020/11/30  101824.0    5.0
# 75441          有限会社加藤工務店  関西地方  京都府     長岡京市   2016/5/30  101305.0    3.0
# 75442            株式会社OWL  関西地方  兵庫県   神戸市中央区   2015/4/30  101812.0    4.0
# 75443           有限会社東洋商事  関東地方  東京都     世田谷区   2022/9/30  103355.0    3.0
# 75444  合資会社シュン・プロモーション中部  関東地方  東京都      杉並区  2022/12/31  102498.0    3.0
#
# [36550 rows x 13 columns]

# %%
df_sales_customer['売上日_曜日'] = df_sales_customer['売上日'].dt.day_name()
df_sales_customer.head()
# Out:
#         売上ID       顧客ID       契約ID        売上日       売上   顧客区分         顧客名  \
# 0  S-1000072  C-1000222  N-1002716 2021-01-01   6000.0    その他  合同会社グループ明伸
# 1  S-1000073  C-1000458  N-1000683 2021-01-01  50000.0  企業規模大    有限会社小川商事
# 2  S-1000074  C-1000599  N-1001044 2021-01-01  10000.0  企業規模中    吉田産業有限会社
# 3  S-1000075  C-1000599  N-1001042 2021-01-01  10000.0  企業規模中    吉田産業有限会社
# 4  S-1000076  C-1000599  N-1001041 2021-01-01  10000.0  企業規模中    吉田産業有限会社
#
#      地域 都道府県     市区町村      初回契約日      社員ID  顧客満足度  売上日_曜日
# 0  関西地方  大阪府   大阪市中央区   2016/1/1  105523.0    3.0  Friday
# 1  中部地方  愛知県  名古屋市中村区   2017/3/1  103462.0    2.0  Friday
# 2   北海道  北海道   札幌市中央区  2017/12/1  100173.0    4.0  Friday
# 3   北海道  北海道   札幌市中央区  2017/12/1  100173.0    4.0  Friday
# 4   北海道  北海道   札幌市中央区  2017/12/1  100173.0    4.0  Friday
